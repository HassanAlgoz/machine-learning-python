# %% [markdown]
# # Linear Regression Exercises

# %%
import pandas as pd

# %% [markdown]
# Data Sources:
#
# - [Simple Linear Regression: Hours vs Marks Data](https://www.kaggle.com/datasets/souradippal/simple-linear-regression-hours-vs-marks-data)
# - [Experience vs Salary Data](https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv)
# - [BMI and Life Expectancy](./datasets/bmi_and_life_expectancy.csv)
