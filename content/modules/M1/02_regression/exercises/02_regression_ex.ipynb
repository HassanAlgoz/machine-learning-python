# %% [markdown]
# # Linear Regression Exercises
#
# Your task is to build a regression model on each of the following datasets.

# %%
import pandas as pd

# %% [markdown]
# 1. [Simple Linear Regression: Hours vs Marks Data](https://www.kaggle.com/datasets/souradippal/simple-linear-regression-hours-vs-marks-data)

# %%
pd.read_csv("./datasets/Rounded_Student_Hours_Studied_vs_Marks_Dataset.csv")

# %% [markdown]
# 2. [Experience vs Salary Data](https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv)

# %%
pd.read_csv("./datasets/Salary Data.csv")

# %% [markdown]
# 3. [BMI and Life Expectancy](./datasets/bmi_and_life_expectancy.csv)

# %%
pd.read_csv("./datasets/bmi_and_life_expectancy.csv")
